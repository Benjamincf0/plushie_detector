# %%
from mylib.split_yolo import split_yolo_dataset
split_yolo_dataset(source_dir="plushie_yolo_test", train_ratio=0.8)
# Out:
# PosixPath('/Users/benjamin/Code/plushie_detector/plushie_yolo_test_split')

# %%
from pathlib import Path

src = Path("penis/plushie_yolo_dataset")

dst = src.with_name(f"{src.name}_split")
print(dst)
# Out:
# penis/plushie_yolo_dataset_split
