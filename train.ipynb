# %%
import torch
print(torch.backends.mps.is_available())
# Out:
# True

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("runs/segment/train6/weights/last.pt", task="segment")  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data="plushie_yolo2_split/config.yaml", device="mps", epochs=80, imgsz=640, workers=4)
# Out:
# New https://pypi.org/project/ultralytics/8.3.228 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.226 🚀 Python-3.14.0 torch-2.9.0 MPS (Apple M3 Pro)
# ...

# %%
results = model.train(
    data="coco_seg.yaml",
    epochs=60,
    imgsz=640,
    batch=8,
    # task="segment",
    # coco=True,                  # telling YOLO the annotations are COCO
    annotations="plushie-coco-dataset/annotations/result_coco.json",
    device="cpu",
    # lr0=0.01,
    # workers=4
)
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[4], line 1
# ----> 1 results = model.train(
#       2     data="coco_seg.yaml",
#       3     epochs=60,
#       4     imgsz=640,
#       5     batch=8,
#       6     # task="segment",
#       7     # coco=True,                  # telling YOLO the annotations are COCO
#       8     annotations="plushie-coco-dataset/annotations/result_coco.json",
#       9     device="cpu",
#      10     # lr0=0.01,
#      11     # workers=4
#      12 )
#
# File /opt/anaconda3/envs/yolo_env/lib/python3.14/site-packages/ultralytics/engine/model.py:773, in Model.train(self, trainer, **kwargs)
#     771     args["resume"] = self.ckpt_path
# --> 773 self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
# ...
