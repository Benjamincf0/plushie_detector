# %%
from ultralytics.data.converter import convert_coco

convert_coco(
    labels_dir="plushie_coco/annotations",
    save_dir="plushie_yolo_test",
    use_segments=True,
)
# Out:
# Annotations /Users/benjamin/Code/plushie_detector/plushie_coco/annotations/result_coco.json: 100% ━━━━━━━━━━━━ 61/61 1.4Kit/s 0.0s
# COCO data converted successfully.
# Results saved to /Users/benjamin/Code/plushie_detector/plushie_yolo_test2
